# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/NFL_win%E2%80%93loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_Frame = pd.read_clipboard()
nfl_Frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1        Dallas Cowboys  493   367     6  0.573              1960
# 1      2     Green Bay Packers  730   553    37  0.567              1921
# 2      3         Chicago Bears  744   568    42  0.565              1920
# 3      4        Miami Dolphins  439   341     4  0.563              1966
# 4      5  New England Patriots  476   383     9  0.554              1960
# 5      6       New York Giants  684   572    33  0.543              1925
# 6      7        Denver Broncos  465   393    10  0.541              1960
# 7      8     Minnesota Vikings  457   387    10  0.541              1961
# 8      9      Baltimore Ravens  181   154     1  0.540              1996
# 9     10   San Francisco 49ers  522   450    14  0.537              1950
# 10    11    Indianapolis Colts  502   441     7  0.532              1953
# 11    12       Oakland Raiders  456   401    11  0.532              1960
# ...

# %%
nfl_Frame.head(10)
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
# 5     6       New York Giants  684   572    33  0.543              1925
# 6     7        Denver Broncos  465   393    10  0.541              1960
# 7     8     Minnesota Vikings  457   387    10  0.541              1961
# 8     9      Baltimore Ravens  181   154     1  0.540              1996
# 9    10   San Francisco 49ers  522   450    14  0.537              1950
#
#   Total Games   Division
# 0         866   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East
# ...

# %%
nfl_Frame.tail(10)
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 22    23         Buffalo Bills  400   460     8  0.465              1960
# 23    24         Detroit Lions  544   641    32  0.460              1930
# 24    25    Cincinnati Bengals  344   408     4  0.458              1968
# 25    26         New York Jets  392   468     8  0.456              1960
# 26    27    New Orleans Saints  338   427     5  0.442              1967
# 27    28        Houston Texans  106   134     0  0.442              2002
# 28    29  Jacksonville Jaguars  155   197     0  0.440              1995
# 29    30       Atlanta Falcons  341   437     6  0.439              1966
# 30    31     Arizona Cardinals  542   732    40  0.428              1920
# 31    32  Tampa Bay Buccaneers  250   393     1  0.389              1976
#
#    Total Games   Division
# 22         868   AFC East
# 23       1,217  NFC North
# 24         756  AFC North
# 25         868   AFC East
# 26         770  NFC South
# ...

# %%
nfl_Frame.columns
# Out:
# Index([u'Rank', u'Team', u'Won', u'Lost', u'Tied', u'Pct.',
#        u'First NFL Season', u'Total Games', u'Division'],
#       dtype='object')

# %%
nfl_Frame.Team
# Out:
# 0           Dallas Cowboys
# 1        Green Bay Packers
# 2            Chicago Bears
# 3           Miami Dolphins
# 4     New England Patriots
# 5          New York Giants
# 6           Denver Broncos
# 7        Minnesota Vikings
# 8         Baltimore Ravens
# 9      San Francisco 49ers
# 10      Indianapolis Colts
# 11         Oakland Raiders
# 12     Pittsburgh Steelers
# 13      Kansas City Chiefs
# 14     Washington Redskins
# 15        Seattle Seahawks
# 16        Cleveland Browns
# 17    Los Angeles Chargers
# 18        Los Angeles Rams
# 19       Carolina Panthers
# 20     Philadelphia Eagles
# 21        Tennessee Titans
# 22           Buffalo Bills
# 23           Detroit Lions
# 24      Cincinnati Bengals
# 25           New York Jets
# 26      New Orleans Saints
# 27          Houston Texans
# 28    Jacksonville Jaguars
# 29         Atlanta Falcons
# 30       Arizona Cardinals
# 31    Tampa Bay Buccaneers
# Name: Team, dtype: object

# %%
nfl_Frame['First NFL Season']
# Out:
# 0     1960
# 1     1921
# 2     1920
# 3     1966
# 4     1960
# 5     1925
# 6     1960
# 7     1961
# 8     1996
# 9     1950
# 10    1953
# 11    1960
# 12    1933
# 13    1960
# 14    1932
# 15    1976
# 16    1950
# 17    1960
# 18    1937
# 19    1995
# 20    1933
# 21    1960
# 22    1960
# 23    1930
# 24    1968
# 25    1960
# 26    1967
# 27    2002
# 28    1995
# 29    1966
# 30    1920
# 31    1976
# Name: First NFL Season, dtype: int64

# %%
subset = DataFrame(nfl_Frame, columns=['First NFL Season','Team'])

# %%
subset.head()
# Out:
#    First NFL Season                  Team
# 0              1960        Dallas Cowboys
# 1              1921     Green Bay Packers
# 2              1920         Chicago Bears
# 3              1966        Miami Dolphins
# 4              1960  New England Patriots

# %%
nfl_Frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1        Dallas Cowboys  493   367     6  0.573              1960
# 1      2     Green Bay Packers  730   553    37  0.567              1921
# 2      3         Chicago Bears  744   568    42  0.565              1920
# 3      4        Miami Dolphins  439   341     4  0.563              1966
# 4      5  New England Patriots  476   383     9  0.554              1960
# 5      6       New York Giants  684   572    33  0.543              1925
# 6      7        Denver Broncos  465   393    10  0.541              1960
# 7      8     Minnesota Vikings  457   387    10  0.541              1961
# 8      9      Baltimore Ravens  181   154     1  0.540              1996
# 9     10   San Francisco 49ers  522   450    14  0.537              1950
# 10    11    Indianapolis Colts  502   441     7  0.532              1953
# 11    12       Oakland Raiders  456   401    11  0.532              1960
# ...

# %%
nfl_Frame.iloc[3]
# Out:
# Rank                             4
# Team                Miami Dolphins
# Won                            439
# Lost                           341
# Tied                             4
# Pct.                         0.563
# First NFL Season              1966
# Total Games                    784
# Division                  AFC East
# Name: 3, dtype: object

# %%
nfl_Frame['Stadium'] = np.arange(32)

# %%
nfl_Frame
# Out:
#     Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0      1        Dallas Cowboys  493   367     6  0.573              1960
# 1      2     Green Bay Packers  730   553    37  0.567              1921
# 2      3         Chicago Bears  744   568    42  0.565              1920
# 3      4        Miami Dolphins  439   341     4  0.563              1966
# 4      5  New England Patriots  476   383     9  0.554              1960
# 5      6       New York Giants  684   572    33  0.543              1925
# 6      7        Denver Broncos  465   393    10  0.541              1960
# 7      8     Minnesota Vikings  457   387    10  0.541              1961
# 8      9      Baltimore Ravens  181   154     1  0.540              1996
# 9     10   San Francisco 49ers  522   450    14  0.537              1950
# 10    11    Indianapolis Colts  502   441     7  0.532              1953
# 11    12       Oakland Raiders  456   401    11  0.532              1960
# ...

# %%
del nfl_Frame['Stadium']

# %%
nfl_Frame.head()
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         866   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
# Add a series to dataframe

# %%
stadiums = Series(["Levi's Stadium",'AT&T Stadium'], index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_Frame['Stadium']=stadiums

# %%
nfl_Frame.head()
# Out:
#    Rank                  Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1        Dallas Cowboys  493   367     6  0.573              1960
# 1     2     Green Bay Packers  730   553    37  0.567              1921
# 2     3         Chicago Bears  744   568    42  0.565              1920
# 3     4        Miami Dolphins  439   341     4  0.563              1966
# 4     5  New England Patriots  476   383     9  0.554              1960
#
#   Total Games   Division         Stadium
# 0         866   NFC East    AT&T Stadium
# 1       1,320  NFC North             NaN
# 2       1,354  NFC North             NaN
# 3         784   AFC East             NaN
# 4         868   AFC East  Levi's Stadium

# %%
# Create Dataframes from dictionaries

# %%
dataDict = {'City':['SF','LA','NYC'],'Population':[873000,388000,8400000]}

# %%
cityFrame = DataFrame(dataDict)

# %%
cityFrame
# Out:
#   City  Population
# 0   SF      873000
# 1   LA      388000
# 2  NYC     8400000
